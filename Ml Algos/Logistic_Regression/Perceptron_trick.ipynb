# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
     X = np.insert(X,0,1,axis=1)
     weights = np.ones(X.shape[1])
     lr = 0.1
    
     for i in range(1000):
         j = np.random.randint(0,100)
         y_hat = step(np.dot(X[j],weights))
         weights = weights + lr*(y[j]-y_hat)*X[j]
        
     return weights[0],weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [1.24866169 0.10490817]
# 1.0

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
def perceptron(X,y):
    
    m = []
    b = []
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(200):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
        m.append(-(weights[1]/weights[2]))
        b.append(-(weights[0]/weights[2]))
        
    return m,b

# %%
m,b = perceptron(X,y)

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: ipython<10 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (9.3.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (8.1.8)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (3.10.6)
# Requirement already satisfied: numpy in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (2.3.0)
# Requirement already satisfied: pillow in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (11.3.0)
# Requirement already satisfied: traitlets<6 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (0.2.3)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install ipympl ipywidgets
# Out:
# Requirement already satisfied: ipympl in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: ipywidgets in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (8.1.8)
# Requirement already satisfied: ipython<10 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (9.3.0)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (3.10.6)
# Requirement already satisfied: numpy in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (2.3.0)
# Requirement already satisfied: pillow in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (11.3.0)
# Requirement already satisfied: traitlets<6 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\rohan\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<10->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib widget
# %matplotlib ipympl  
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots(figsize=(9,5))

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*m[0] +b[0]
ax.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
line, = ax.plot(x_i, x_i*m[0] +b[0] , 'r-', linewidth=2)
plt.ylim(-3,3)
def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*m[i] + b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=200, interval=100)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(X,y)
# Out:
# LogisticRegression()

# %%
m = -(lor.coef_[0][0]/lor.coef_[0][1])
b = -(lor.intercept_/lor.coef_[0][1])

# %%
x_input1 = np.linspace(-3,3,100)
y_input1 = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.plot(x_input1,y_input1,color='black',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
