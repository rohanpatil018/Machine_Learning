# %%
import numpy as np
import pandas as pd

# %%
w = np.random.randn(30)  
x = np.random.randn(30)
n=len(w)
f=0
b=6

for i in range(n):
    f=f+w[i]*x[i]
f=f+b

f
# Out:
# np.float64(2.4141650880255736)

# %%
f=np.dot(w,x)+b
f
# Out:
# np.float64(2.414165088025573)

# %%
d=np.random.randn(30)

for j in range(0,n):
    w[j]=w[j]-0.1*d[j]
    print(w)
# Out:
# [ 5.64911239e-01 -2.38655018e+00 -1.50191692e-01 -8.03435490e-02
#   1.89866667e+00 -1.27977691e+00  5.59405399e-01  2.17337297e-01
#   1.24635989e-03  5.37010704e-01  1.62711861e+00  1.26661151e+00
#   7.39906437e-01  1.76943564e+00 -5.75623171e-01  2.45878626e+00
#   6.20896740e-01  1.08752790e-01 -4.10617421e-01 -3.09690093e-01
#  -5.31731618e-01 -1.50910660e+00  1.23667048e+00  2.46668579e+00
#  -1.60740620e-01  2.64781407e-01  7.73363438e-01 -1.20713441e+00
#  -1.13550058e+00 -1.99562019e-01]
# [ 5.64911239e-01 -2.37521583e+00 -1.50191692e-01 -8.03435490e-02
#   1.89866667e+00 -1.27977691e+00  5.59405399e-01  2.17337297e-01
#   1.24635989e-03  5.37010704e-01  1.62711861e+00  1.26661151e+00
#   7.39906437e-01  1.76943564e+00 -5.75623171e-01  2.45878626e+00
#   6.20896740e-01  1.08752790e-01 -4.10617421e-01 -3.09690093e-01
#  -5.31731618e-01 -1.50910660e+00  1.23667048e+00  2.46668579e+00
#  -1.60740620e-01  2.64781407e-01  7.73363438e-01 -1.20713441e+00
# ...

# %%
w=w-0.1*d
print(w)
# Out:
# [ 0.4671695  -2.36388148 -0.15904805 -0.05970827  2.06297866 -1.40215441
#   0.74390644  0.35071936 -0.09858712  0.62701437  1.92152724  1.32992112
#   0.48788712  1.96246253 -0.60456488  2.42534704  0.36880319  0.39385811
#  -0.38029964 -0.35099623 -0.8283265  -1.639239    1.4709378   1.81686455
#  -0.0928571   0.28673622  0.78708626 -1.39742408 -1.80001079 -0.16557221]
