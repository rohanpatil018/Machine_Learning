# %% [markdown]
# Basically it is used to predict the numbers

# %%
"""
Linear Regression:
1)Find a pattern in a old data
2)straight line
3)line

[[value]]->2d List

X=[[1],[2],[3],[4],[5]]
in Ml row->example
and Column->Feature

1->it is not about the line,it's about the story
2->Accuracy is not the goal
3->5 rows to start

"""
# Out:
# '\nLinear Regression:\n1)Find a pattern in a old data\n2)straight line\n3)line\n'

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

X=[[1],[2],[3],[4],[5]]
y=[30,40,57,90,98]
model.fit(X,y)

hours=float(input("Enter How many Hours you Studied: "))

predicted_marks=model.predict([[hours]])

print(f"Based in your hours: {hours} you can score upto : {predicted_marks} marks")
# Out:
# Enter How many Hours you Studied:  1
# Based in your hours: 1.0 you can score upto : [25.8] marks
