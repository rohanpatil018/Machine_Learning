# %%
import numpy as np

# %%
a=np.array(42)
print(a)
print(type(a))
# Out:
# 42
# <class 'numpy.ndarray'>

# %%
b=np.array([[1,2,3],[4,5,6]])
print(b)
print(type(b))
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>

# %%
c=np.array([[[1,2],[3,4],[5,6]]])
print(c)
print(c.ndim)
# Out:
# [[[1 2]
#   [3 4]
#   [5 6]]]
# 3

# %%
d=np.array([1,2,3,4,5],ndmin=5)
print(d)
# Out:
# [[[[[1 2 3 4 5]]]]]
